# %%
from omero.gateway import BlitzGateway
import ezomero

101
# Out:
# 101

# %%
#conn = BlitzGateway(host='ws://idr.openmicroscopy.org/omero-ws', username='public', passwd='public', secure=True)
conn = BlitzGateway(host='localhost', username='root', passwd='omero', secure=True)
print(conn.connect())
conn.c.enableKeepAlive(60)
# Out:
# True

# %%
#choose a dataset
datatype = "Dataset" # "plate", "dataset", "image"
data_id = 	502
nucl_channel = 0

#validate that data_id matches datatype
if datatype == "Plate":
    plate = conn.getObject("Plate", data_id)
    print('Plate Name: ', plate.getName())
elif datatype == "Dataset":
    dataset = conn.getObject("Dataset", data_id)
    print('Dataset Name: ', dataset.getName())
elif datatype == "Image":
    image = conn.getObject("Image", data_id)
    print('Image Name: ', image.getName())
# Out:
# Dataset Name:  day7

# %%
import pandas as pd

def camel_to_space(name):
    """
    Convert camelCase to space-separated words
    Keeps consecutive capital letters together (e.g., 'ID', 'RNA')
    """
    result = []
    # Track if we're in a sequence of capitals
    in_capitals = False
    
    for i, char in enumerate(name):
        # Check if this is a capital letter
        if char.isupper():
            # Check if previous character exists and was not a capital
            if i > 0 and not in_capitals:
                result.append(' ')
            in_capitals = True
        else:
            in_capitals = False
            
        result.append(char)
    
    return ''.join(result).strip()

def read_metadata_template(excel_path):
    """
    Read Excel metadata template and convert to a dictionary format
    for OMERO annotations, specifically from AssayConditions tab.
    Converts column headers from camelCase to space-separated words.
    """
    # Read the full sheet without assuming header position
    df = pd.read_excel(excel_path, sheet_name='AssayConditions', header=None)
    
    # Find the row containing the actual column headers
    header_row = df[df[0] == 'Plate'].index[0]
    
    # Read the Excel again, now with correct header position
    df = pd.read_excel(excel_path, 
                      sheet_name='AssayConditions', 
                      header=header_row)
    
    # Rename columns to convert from camelCase
    df.columns = [camel_to_space(col) if col != 'Well' else col for col in df.columns]
    
    # Convert DataFrame to dictionary where keys are Well IDs
    metadata_dict = df.set_index('Well').to_dict('index')
    return metadata_dict

def add_metadata_to_object(conn, object_type, object_id, metadata, namespace):
    """
    Add or update metadata as map annotation to an OMERO object using ezomero.
    Preserves existing keys that are not in the new metadata.
    
    Args:
        conn: OMERO connection
        object_type: String indicating OMERO object type (e.g., "Image", "Dataset")
        object_id: ID of the OMERO object
        metadata: Dictionary of metadata key-value pairs
        namespace: Namespace for the annotation
    """
    # Get existing map annotation IDs
    existing_ann_ids = ezomero.get_map_annotation_ids(
        conn,
        object_type,
        object_id,
        ns=namespace
    )
    
    # Initialize merged metadata dictionary
    merged_metadata = {}
    
    if existing_ann_ids:
        # Get the first annotation values
        obj = conn.getObject(object_type, object_id)
        links_to_delete = []
        
        for ann in obj.listAnnotations(ns=namespace):
            if ann.id == existing_ann_ids[0]:  # Use first annotation if multiple exist
                merged_metadata = dict(ann.getValue())
                links_to_delete.append(ann.link.id)
                break
        
        # Unlink old annotations
        if links_to_delete:
            print(f"Unlinking {len(links_to_delete)} annotations")
            conn.deleteObjects("ImageAnnotationLink", links_to_delete, wait=True)
    
    # Filter out any NaN values from the new metadata
    clean_metadata = {k: str(v) for k, v in metadata.items() if pd.notna(v)}
    
    # Update merged metadata with new values
    merged_metadata.update(clean_metadata)
    
    # Create new annotation with merged metadata
    map_ann_id = ezomero.post_map_annotation(
        conn,
        object_type,
        object_id,
        merged_metadata,
        namespace
    )
    return map_ann_id


def remove_metadata_from_images(conn, dataset_id, namespace=None, delete_annotations=True):
    """
    Remove map annotations from all images in a dataset
    
    Args:
        conn: OMERO connection
        dataset_id: ID of the dataset containing images
        namespace: Optional - specific namespace to remove. If None, removes all map annotations
        delete_annotations: If True, deletes the annotations. If False, just unlinks them
    """
    # Get all images from dataset
    dataset = conn.getObject("Dataset", dataset_id)
    images = list(dataset.listChildren())
    print(f"Found {len(images)} images in dataset")
    
    for image in images:
        print(f"Processing image {image.getName()}")
        
        # Get annotations
        to_delete = []
        for ann in image.listAnnotations(ns=namespace):
            if delete_annotations:
                to_delete.append(ann.id)
            else:
                to_delete.append(ann.link.id)
        
        if to_delete:
            if delete_annotations:
                # Delete the annotations completely
                print(f"Deleting {len(to_delete)} annotations")
                conn.deleteObjects("Annotation", to_delete, wait=True)
            else:
                # Just unlink the annotations
                print(f"Unlinking {len(to_delete)} annotations")
                conn.deleteObjects("ImageAnnotationLink", to_delete, wait=True)

# %%
# Read metadata template
excel_path = "D:\\OneDrive\\LUMC\\Projects\\Mazene Hochane\\MIHCSME Template_MH.xlsx"
metadata_dict = read_metadata_template(excel_path)

# Define namespace for annotations
namespace = "openmicroscopy.org/omero/experimental/metadata"

# Get all images from dataset
dataset = conn.getObject("Dataset", data_id)
images = list(dataset.listChildren())  # Convert to list for length check and reuse
num_images = len(images)
num_metadata_rows = len(metadata_dict)

print(f"Found {num_images} images in dataset")
print(f"Found {num_metadata_rows} rows in metadata")

if num_images != num_metadata_rows:
    print("Warning: Number of images doesn't match number of metadata rows!")
    print("Please check your data before proceeding.")
else:
    # Convert metadata_dict values to list to access by index
    metadata_list = list(metadata_dict.values())
    
    # Loop through images and metadata together
    for i, image in enumerate(images):
        # Get metadata for this position
        metadata = metadata_list[i]
        
        # Add metadata to image
        map_ann_id = add_metadata_to_object(
            conn,
            "Image",
            image.getId(),
            metadata,
            namespace
        )
        print(f"Added metadata to image {image.getName()} with annotation ID {map_ann_id}")
# Out:
# Found 72 images in dataset
# Found 72 rows in metadata
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 01)].tif with annotation ID 2261
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 02)].tif with annotation ID 2262
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 03)].tif with annotation ID 2263
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 04)].tif with annotation ID 2264
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 05)].tif with annotation ID 2265
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 06)].tif with annotation ID 2266
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 07)].tif with annotation ID 2267
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 08)].tif with annotation ID 2268
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 09)].tif with annotation ID 2269
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 10)].tif with annotation ID 2270
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 11)].tif with annotation ID 2271
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 12)].tif with annotation ID 2272
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 13)].tif with annotation ID 2273
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 14)].tif with annotation ID 2274
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 15)].tif with annotation ID 2275
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 16)].tif with annotation ID 2276
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 17)].tif with annotation ID 2277
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 18)].tif with annotation ID 2278
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 19)].tif with annotation ID 2279
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 20)].tif with annotation ID 2280
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 21)].tif with annotation ID 2281
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 22)].tif with annotation ID 2282
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 23)].tif with annotation ID 2283
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 24)].tif with annotation ID 2284
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 25)].tif with annotation ID 2285
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 26)].tif with annotation ID 2286
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 27)].tif with annotation ID 2287
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 28)].tif with annotation ID 2288
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 29)].tif with annotation ID 2289
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 30)].tif with annotation ID 2290
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 31)].tif with annotation ID 2291
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 32)].tif with annotation ID 2292
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 33)].tif with annotation ID 2293
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 34)].tif with annotation ID 2294
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 35)].tif with annotation ID 2295
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 36)].tif with annotation ID 2296
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 37)].tif with annotation ID 2297
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 38)].tif with annotation ID 2298
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 39)].tif with annotation ID 2299
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 40)].tif with annotation ID 2300
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 41)].tif with annotation ID 2301
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 42)].tif with annotation ID 2302
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 43)].tif with annotation ID 2303
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 44)].tif with annotation ID 2304
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 45)].tif with annotation ID 2305
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 46)].tif with annotation ID 2306
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 47)].tif with annotation ID 2307
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 48)].tif with annotation ID 2308
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 49)].tif with annotation ID 2309
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 50)].tif with annotation ID 2310
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 51)].tif with annotation ID 2311
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 52)].tif with annotation ID 2312
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 53)].tif with annotation ID 2313
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 54)].tif with annotation ID 2314
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 55)].tif with annotation ID 2315
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 56)].tif with annotation ID 2316
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 57)].tif with annotation ID 2317
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 58)].tif with annotation ID 2318
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 59)].tif with annotation ID 2319
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 60)].tif with annotation ID 2320
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 61)].tif with annotation ID 2321
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 62)].tif with annotation ID 2322
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 63)].tif with annotation ID 2323
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 64)].tif with annotation ID 2324
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 65)].tif with annotation ID 2325
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 66)].tif with annotation ID 2326
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 67)].tif with annotation ID 2327
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 68)].tif with annotation ID 2328
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 69)].tif with annotation ID 2329
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 70)].tif with annotation ID 2330
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 71)].tif with annotation ID 2331
# Unlinking 1 annotations
# object group 0
# Added metadata to image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 72)].tif with annotation ID 2332

# %% [markdown]
# ## Remove all annotations

# %%
# Usage example:
# To delete annotations:
remove_metadata_from_images(
    conn, 
    data_id,
    namespace="openmicroscopy.org/omero/experimental/metadata",
    delete_annotations=True
)

# To just unlink annotations:
# remove_metadata_from_images(
#     conn, 
#     dataset_id,
#     namespace="openmicroscopy.org/omero/experimental/metadata",
#     delete_annotations=False
# )
# Out:
# Found 72 images in dataset
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 01)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 02)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 03)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 04)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 05)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 06)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 07)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 08)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 09)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 10)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 11)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 12)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 13)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 14)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 15)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 16)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 17)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 18)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 19)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 20)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 21)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 22)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 23)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 24)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 25)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 26)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 27)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 28)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 29)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 30)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 31)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 32)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 33)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 34)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 35)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 36)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 37)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 38)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 39)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 40)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 41)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 42)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 43)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 44)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 45)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 46)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 47)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 48)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 49)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 50)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 51)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 52)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 53)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 54)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 55)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 56)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 57)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 58)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 59)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 60)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 61)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 62)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 63)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 64)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 65)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 66)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 67)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 68)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 69)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 70)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 71)].tif
# Deleting 2 annotations
# Processing image 14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 [14-6-24_FUCCI_PDLO_Day7_plate1-fixed_007.nd2 (series 72)].tif
# Deleting 2 annotations
